# %% [markdown]
# # DataViewer
# A Jupyter Notebook for visualizing the data

# %%
# %matplotlib notebook

# %%
import sys
sys.path.append('../')

# %%
import traffic.dbutil as dbutil
import traffic.plotting as tp

# %%
rows = dbutil.get_rows(26)

# %%
canvas = tp.canvas_from_data(rows)

# %%
canvas.figure
